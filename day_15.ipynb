# %%
import numpy as np

learning_rate = 0.01
x = np.array([1,2,3,4,5])
y = np.array([3000,3500,5000,5500,6500])
m=0
b=0
for i in range (1000):
    y_hat = m*x + b
    error = np.mean(y_hat - y)
    dm = np.mean((y_hat - y)*x)
    db = np.mean(y_hat - y)
    m = m - learning_rate*dm
    b = b - learning_rate*db
print(m,b)
# Out:
# 982.9429107634014 1700.5497745010514

# %%
learning_rate = 0.01
tol = 1e-6
pre_loss = float("inf")
converged_epoch = None
m_history = []
b_history = []
loss_history = []
b=0
for i in range (1000):
    y_hat = m*x + b
    error = np.mean(y_hat - y)
    dm = np.mean((y_hat - y)*x)
    db = np.mean(y_hat - y)
    m = m - learning_rate*dm
    b = b - learning_rate*db
    m_history.append(m)
    b_history.append(b)
    loss_history.append(error)

    if(abs(pre_loss - error )<tol):
        converged_epoch = i
        print(f"Converged at epoch {i}")
    pre_loss = error
m_history[0],b_history[0], loss_history[0]
# Out:
# (np.float64(1045.4517068506761),
#  np.float64(17.119605387055852),
#  np.float64(-1711.9605387055853))

# %%
import numpy as np
x = np.array([1,2,3,4,5])
y = np.array([3000,3500,5000,5500,6500])
learning_rate = 0.1
tol = 1e-6
m=0
b=0
prev_loss = float("inf")
converged_epoch = None
m_history = []
b_history = []
loss_history = []
n = len(x)
for i in range(1000):
    indices = np.random.permutation(n)
    for j in indices:
        x_j = x[j]
        y_j = y[j]
        y_hat = m*x_j + b
        error = y_hat - y_j 
        dm = error * x_j
        db = error
        m = m - learning_rate * dm
        b = b - learning_rate * db
m,b
# Out:
# (np.float64(1092.8707886413004), np.float64(2082.3521257201533))

# %%
from sklearn.linear_model import SGDRegressor
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler

model = make_pipeline(StandardScaler(),SGDRegressor(max_iter = 1000, learning_rate = "constant", eta0=0.01,random_state=42))
model


x=np.array([1,2,3,4,5]).reshape(-1,1)
y = np.array([3000, 3500,5000,5500,6500])
model.fit(x,y)
print(model.predict(np.array([6]).reshape(-1,1)))
# Out:
# [7397.35657664]

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.pipeline import make_pipeline
data = pd.read_csv("Advertising.csv")
print(data.head())
x = data[["TV","radio","newspaper"]]
y = data["sales"]
print(x,y)
x_train,x_test,y_train,y_test = train_test_split(x,y, test_size=0.2, random_state=42)
model = make_pipeline(
    StandardScaler(),
    SGDRegressor(max_iter=10000, learning_rate = "constant", eta0=0.01)
    )
model.fit(x_train,y_train)
print(model.predict(x_test))
# Out:
#    Unnamed: 0     TV  radio  newspaper  sales
# 0           1  230.1   37.8       69.2   22.1
# 1           2   44.5   39.3       45.1   10.4
# 2           3   17.2   45.9       69.3    9.3
# 3           4  151.5   41.3       58.5   18.5
# 4           5  180.8   10.8       58.4   12.9
#         TV  radio  newspaper
# 0    230.1   37.8       69.2
# 1     44.5   39.3       45.1
# 2     17.2   45.9       69.3
# 3    151.5   41.3       58.5
# 4    180.8   10.8       58.4
# ..     ...    ...        ...
# 195   38.2    3.7       13.8
# 196   94.2    4.9        8.1
# 197  177.0    9.3        6.4
# 198  283.6   42.0       66.2
# 199  232.1    8.6        8.7
#
# [200 rows x 3 columns] 0      22.1
# 1      10.4
# 2       9.3
# 3      18.5
# 4      12.9
#        ...
# 195     7.6
# 196     9.7
# 197    12.8
# 198    25.5
# 199    13.4
# Name: sales, Length: 200, dtype: float64
# ---------------------------------------------------------------------------
# ...

# %%
model = make_pipeline(
    StandardScaler(),
    SGDRegressor(max_iter=10000, learning_rate = "constant", eta0=0.01, random_state=42)
    )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 model = make_pipeline(
#       2     StandardScaler(),
#       3     SGDRegressor(max_iter=10000, learning_rate = "constant", eta0=0.01, random_state=42)
#       4     )
#
# NameError: name 'make_pipeline' is not defined

# %%
y_pred = model.predict(x_test)
y_pred, y_test
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 y_pred = model.predict(x_test)
#       2 y_pred, y_test
#
# NameError: name 'model' is not defined
