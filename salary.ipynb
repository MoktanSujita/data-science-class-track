# %%
import pandas as pd

data = pd.read_csv("Salaries.csv")
# data.describe()
mean_salaries=data['BasePay'].mean()
standard_deviation=data['OtherPay'].std()
unique_job=data['JobTitle'].unique()
nsum=(data['JobTitle']=='TRANSIT OPERATOR').sum()
mean_salaries
standard_deviation
unique_job
nsum
# Out:
# np.int64(2388)

# %%
import numpy as np

first_array = np.arange(1,3)

second_array = pow(first_array,2)+2
#second_array = np.square(first_array)+2
second_array
# Out:
# array([3, 6])

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.linspace(-5,5,11)
y = x **2 + 2
plt.plot(x,y)
